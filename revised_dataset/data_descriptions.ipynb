# %% [markdown]
# # New dataset descriptions
#
# $\textbf{STUDY: ADNI3}$
#
# $\bullet$ Folder_name: 3_ASMP_Sagittal_AD
#
# Project/Phase: ADNI3
#
# Research Group: AD
#
# Image Description: Accelerated Sagittal MPRAGE
#
# Modality: MRI
#
# Acquisition Plane: Sagittal
#
# $\bullet$ Folder_name: 3_ASMP_Sagittal_MCI
#
# Project/Phase: ADNI3
#
# Research Group: MCI
#
# Image Description: Accelerated Sagittal MPRAGE
#
# Modality: MRI
#
# Acquisition Plane: Sagittal
#
#
# $\bullet$ Folder_name: 3_ASMP_Sagittal_CN
#
# Project/Phase: ADNI3
#
# Research Group: CN
#
# Image Description: Accelerated Sagittal MPRAGE
#
# Modality: MRI
#
# Acquisition Plane: Sagittal
#
# =======================================================
#
# $\textbf{STUDY: ADNIGO and ADNI2}$
#
# Project/Phase: ADNIGO and ADNI2
#
# Research Group: CN, MCI, AD
#
# Image Description: (i)MPRAGE  AND (ii)MP-RAGE
#
# Modality: MRI
#
# Acquisition Plane: Sagittal
#
#
# NOTES: There was no result returned for the search Accelerated Sagittal MP-RAGE for this study.
#
# ========================================================
#
# $\textbf{ STUDY: ADNI1}$
#
# Project/Phase: ADNI1
#
# Research Group: CN, MCI, AD
#
# Image Description: MP-RAGE
#
# Modality: MRI
#
# Acquisition Plane: Sagittal
